# %% [markdown]
# Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Wrangling

# %%
df = pd.read_csv('/content/movies.csv')
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# Data Cloning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df.nunique()
# Out:
# budget                   436
# genres                  1175
# homepage                1691
# id                      4803
# keywords                4222
# original_language         37
# original_title          4801
# overview                4800
# popularity              4802
# production_companies    3697
# production_countries     469
# release_date            3280
# revenue                 3297
# runtime                  156
# spoken_languages         544
# status                     3
# tagline                 3944
# title                   4800
# vote_average              71
# vote_count              1609
# dtype: int64

# %%
df.vote_average
# Out:
# 0       7.2
# 1       6.9
# 2       6.3
# 3       7.6
# 4       6.1
#        ...
# 4798    6.6
# 4799    5.9
# 4800    7.0
# 4801    5.7
# 4802    6.3
# Name: vote_average, Length: 4803, dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace = True)
df.duplicated().any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df.drop(['id', 'homepage', 'tagline',  'overview', 'keywords', 'production_companies',  'release_date'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (4803, 13)

# %%
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# original_language       0
# original_title          0
# popularity              0
# production_countries    0
# revenue                 0
# runtime                 2
# spoken_languages        0
# status                  0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
df.dropna(inplace = True)
df.isnull().any().sum()
# Out:
# 0

# %%
df['genres'] = df['genres'].apply(lambda x: x.split("|")[0])
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_countries     revenue  runtime  \
# ...

# %%
df['profit'] = df.revenue - df.budget
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_countries     revenue  runtime  \
# ...

# %%
def catigorize_col (df, col, labels):

    edges = [df[col].describe()['min'],
             df[col].describe()['25%'],
             df[col].describe()['50%'],
             df[col].describe()['75%'],
             df[col].describe()['max']]

    df[col] = pd.cut(df[col], edges, labels = labels, duplicates='drop')
    return df

# %%
labels = ['not_popular', 'below_avg', 'average', 'popular']
catigorize_col(df, 'vote_average', labels)

df['vote_average'].unique()
# Out:
# ['popular', 'average', 'below_avg', 'not_popular', NaN]
# Categories (4, object): ['not_popular' < 'below_avg' < 'average' < 'popular']

# %%
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# original_language       0
# original_title          0
# popularity              0
# production_countries    0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# vote_average            0
# vote_count              0
# profit                  0
# dtype: int64

# %%
def categorize_col(df, col, labels):
    edges = [
        df[col].min(),
        df[col].quantile(0.33),
        df[col].quantile(0.66),
        df[col].max()
    ]
    df[col + '_category'] = pd.cut(
        df[col],
        bins=edges,
        labels=labels,
        include_lowest=True
    )
    return df
labels = ['low', 'average', 'high']
df = categorize_col(df, 'profit', labels)
print(df)
print(df['profit_category'].unique())
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#      original_language                            original_title  popularity  \
# 0                   en                                    Avatar  150.437577
# ...

# %%
df.profit.isnull().sum()
# Out:
# 0

# %%
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# original_language       0
# original_title          0
# popularity              0
# production_countries    0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# vote_average            0
# vote_count              0
# profit                  0
# profit_category         0
# dtype: int64

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_countries     revenue  runtime  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4739 entries, 0 to 4802
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4739 non-null   int64
#  1   genres                4739 non-null   object
#  2   original_language     4739 non-null   object
#  3   original_title        4739 non-null   object
#  4   popularity            4739 non-null   float64
#  5   production_countries  4739 non-null   object
#  6   revenue               4739 non-null   int64
#  7   runtime               4739 non-null   float64
#  8   spoken_languages      4739 non-null   object
#  9   status                4739 non-null   object
#  10  title                 4739 non-null   object
#  11  vote_average          4739 non-null   category
#  12  vote_count            4739 non-null   int64
#  13  profit                4739 non-null   int64
#  14  profit_category       4739 non-null   category
# ...

# %% [markdown]
# ## Now lets do some analysis

# %% [markdown]
# Q1: Do movies with high popularity achive high revenvue?

# %%
df['popularity'].mean()
# Out:
# 21.780482794682424

# %%
less_popular = df.query('popularity <= 0.647')
more_popular = df.query('popularity >  0.647')

# %%
print(less_popular.revenue.mean(), more_popular.revenue.mean())
# Out:
# 574253.105839416 88452516.96640538

# %% [markdown]
# Q2: What are the most filmed genres in this whole dataset?

# %%
top_genres = df['genres'].value_counts()

plt.figure(figsize=(15, 6))
ax = top_genres.plot(
    kind="bar",
    color="skyblue",
    edgecolor="black",
    width=0.6
)

# Add Title and Labels with Improved Font Sizes
plt.title("The Most Filmed Genres", fontsize=16, fontweight='bold', pad=20)
plt.xlabel("Genres", fontsize=14, labelpad=10)
plt.ylabel("Count", fontsize=14, labelpad=10)

# Enhance Tick Parameters
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=12, padding=3)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-129-ff65d616824e>:29: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()  # Adjust layout to avoid clipping

# %%
top_3_genres = df['genres'].value_counts().nlargest(3)
plt.figure(figsize=(10, 5))
ax = top_3_genres.plot( kind="bar", color=["#FF9999", "#66B2FF", "#99FF99"],  edgecolor="black", width=0.6)
plt.title("Top 3 Most Filmed Genres", fontsize=16, fontweight='bold', pad=20)
plt.xlabel("Genres", fontsize=14, labelpad=10)
plt.ylabel("Count", fontsize=14, labelpad=10)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=12, padding=3)
plt.tight_layout()
plt.show()
print("Top 3 Genres and Counts:")
print(top_3_genres)
# Out:
# Top 3 Genres and Counts:
# genres
# [{"id": 18, "name": "Drama"}]                                      361
# [{"id": 35, "name": "Comedy"}]                                     280
# [{"id": 18, "name": "Drama"}, {"id": 10749, "name": "Romance"}]    164
# Name: count, dtype: int64

# %%
df['genres'].describe()
# Out:
# count                              4739
# unique                             1172
# top       [{"id": 18, "name": "Drama"}]
# freq                                361
# Name: genres, dtype: object

# %% [markdown]
# Q3: Is there a correlation between a movie budget and its revenue?

# %%
plt.scatter(df['budget'],df['revenue']);
plt.title("movie budget against its revenue");
plt.xlabel('budget', fontsize=10);
plt.ylabel('revenue',fontsize=10);

# %% [markdown]
# # Conclusions:

# %% [markdown]
# Ans 1: More popular movies recieve way more revenue than the less popular movies.
#
# Ans 2: Top 3 generes in whole data set are- Drama, Comedy and Romance.
#
# Ans 3: There is positive correlation between budget and revenue, indicating a relation between them with little outliers.
